# %%
from statistics import median
import pandas as pd
import matplotlib.pyplot as plt

# %%
df4 = pd.read_csv('./Datasets/Rolamento_com_Falha/Full DE BAll.csv',delimiter=';')

# %%
plt.figure(figsize =(20, 10))
df4.boxplot()
bplots=df4.boxplot()
plt.show()

# %%
plt.hist(df4, 10, rwidth=1.9)
plt.show()

# %%
somatoria =df4.sum()
maximo = df4.max()
minimo = df4.min()
contar = df4.count()
mediana = df4.median() 
media = df4.mean()
desvpad = df4.std() 
variancia = df4.var() 

print ('\n\n Somatória: \n ' + str(somatoria) + '\n\n\n')
print ('\n\n Máximo: \n ' + str(maximo)+ '\n\n\n')
print ('\n\n Mínimo: \n ' + str(minimo)+ '\n\n\n')
print ('\n\n Média:  \n' + str(media)+ '\n\n\n')
print (' \n\n Mediana:  \n' + str(mediana)+ '\n\n\n')
print ('\n\n Contar: \n' + str(contar)+ '\n\n\n')
print ('\n\n Desvio Padrão:  \n' + str(desvpad)+ '\n\n\n')
print ('\n\n Variância: \n' + str(variancia)+ '\n\n\n')
# Out:
#  Somatória:
#  -0.0027614    1545.261427
# -0.072121      472.579524
# -0.31447       555.109152
# 0.090314       510.408047
# dtype: float64
#
#
#
#
#
#  Máximo:
#  -0.0027614    0.60393
# -0.072121     0.63967
# -0.31447      0.60458
# 0.090314      0.67151
# dtype: float64
#
#
#
#
#
#  Mínimo:
#  -0.0027614   -0.60702
# -0.072121    -0.65965
# -0.31447     -0.56674
# 0.090314     -0.72056
# dtype: float64
#
#
#
#
#
#  Média:
# -0.0027614    0.012607
# -0.072121     0.003892
# -0.31447      0.004567
# 0.090314      0.004199
# dtype: float64
#
#
#
#
#
#  Mediana:
# -0.0027614    0.012832
# -0.072121     0.003736
# -0.31447      0.003898
# 0.090314      0.003736
# dtype: float64
#
#
#
#
#
#  Contar:
# -0.0027614    122570
# -0.072121     121409
# -0.31447      121555
# 0.090314      121555
# dtype: int64
#
#
#
#
#
#  Desvio Padrão:
# -0.0027614    0.138663
# -0.072121     0.139015
# -0.31447      0.147179
# 0.090314      0.153579
# dtype: float64
#
#
#
#
#
#  Variância:
# -0.0027614    0.019227
# -0.072121     0.019325
# -0.31447      0.021662
# 0.090314      0.023586
# dtype: float64
